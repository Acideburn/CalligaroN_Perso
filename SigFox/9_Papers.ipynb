# %% [markdown]
# # Ce jupyter s'appuie sur un paper :
# https://hal.telecom-paris.fr/hal-02367908/document
# ## Il a été réalisé en collaboration avec Frederic Haykal
# donc une partie du code sera commune à nos deux rendus.

# %% [markdown]
# # Idée maitresse de la solution :
# Nous allons produire un modèle par base.\
# Ce modèle va apprendre à produire la distance entre la base et les messages reçus par cette base en s'appuyant sur le rssi.\
# Le modèle va modéliser les perturbations terrain afin de pouvoir prédire une distance avec un rssi non fiable.

# %% [markdown]
# ### Explication de l'idée
# Cas du GPS : le rssi donne la puissance recu du signal. ainsi avec cet valeur on peut définir la distance parcouru par le signal.\
# Notre cas : Mais par construction dans notre cas ce rssi est perturbé par autre chose que la distance (le terrain). Nous utiliserons donc du Machine Learning pour apprendre ces perturbations et arriver a calculer cette distance.

# %% [markdown]
# ### de plus
# On remarque que si l'on met les distances au lieu des 1 dans la df_feature on a de très bon résultat.\
# Notre objectif sera donc de créer cette matrice dans le jeu de test en s'appuyant sur un modèle appris sur le train.
#
# Un dernier model prédira la position du message en s'appuyant sur cette nouvelle matrice.\
# NB : nous rajouterons également les barycentres venant des autres jupyter pour encore augmenter la précision.
#
# Comme on peut le voir à la fin, malgré un overfit non négligeable les résultats sont prometteurs

# %%
import pandas as pd
import numpy as np
from IotTools import *
#from IpyTools import *
pd.options.mode.chained_assignment = None  # default='warn'
import pickle
from vincenty import vincenty

from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import VotingRegressor

from sklearn.model_selection import cross_val_predict

# %%
df_mess_train = pd.read_csv('mess_train_list.csv')
df_mess_test = pd.read_csv('mess_test_list.csv')
pos_train = pd.read_csv('pos_train_list.csv')
listOfBs = np.union1d(df_mess_train.bsid.unique(),df_mess_test.bsid.unique())

# %%
size = len(listOfBs)
size
# Out:
# 259

# %% [markdown]
# # On corrige les bases outliers

# %%
X_train= Correct_Bases (df_mess_train)
X_train[X_train.bs_lat>64].shape[0];
# Out:
# Nous avons 27 bases outliers
# Base 9949 non vu
# il reste 0 base avec lat >60

# %%
X_test= Correct_Bases (df_mess_test)
X_test[X_test.bs_lat>64].shape[0];
# Out:
# Nous avons 23 bases outliers
# Correction manuelle de la bsid 9949
# il reste 0 base avec lat >60

# %% [markdown]
# # On créer la liste des coordonnées de toutes les bases

# %%
#On crééer une matrice contenant les coordonnées des bases
base_coord = pd.concat([X_train,X_test]).drop_duplicates(subset='bsid')[['bsid','bs_lat','bs_lng']].set_index('bsid')

# %% [markdown]
# # On créer une feature distance

# %%
msg_coord = (pos_train.set_index(keys=df_mess_train.messid.values).reset_index()).groupby('index').mean()
X_train['dist']=0
for i in X_train.index:
    bs_Coord = (X_train.iloc[i].bs_lat,X_train.iloc[i].bs_lng)
    msg_Coord = (msg_coord.loc[X_train.iloc[i].messid].lat,msg_coord.loc[X_train.iloc[i].messid].lng)
    X_train.loc[i,'dist']=vincenty(bs_Coord,msg_Coord)
X_train.head(1)
# Out:
#                      messid  bsid       did  nseq   rssi       time_ux  \
# 0  573bf1d9864fce1a9af8c5c9  2841  473335.0   0.5 -121.5  1.463546e+12
#
#       bs_lat      bs_lng      dist
# 0  39.617794 -104.954917  1.270478

# %% [markdown]
# # La fct feat matrice propre a notre cas où l'on fait apparaitre le Rssi

# %%
def feat_mat_const(df, listOfBs):
    """On a rajouté une colonne contenant le nombre de détection par msg
    cela servira à identifié la pondération de la prédiction
    """
    df_group = df.groupby("messid", as_index=False)
    nb_mess = len(df.messid.unique())
    df_feat = pd.DataFrame(np.zeros((nb_mess, len(listOfBs))), columns=listOfBs, index=df.messid.unique())
    id_list = [0] * nb_mess

    for i, (key, elmt) in enumerate(df_group):
        df_feat.loc[key,elmt.bsid]= elmt.rssi.values #ici on met le rssi au lieu des 1 
        id_list[i] = key
        
    """Rajout des BaryCentres"""
            
    a =df.rssi.values
    df['rssi_reshape'] = (10**(a/10))
    df['bs_lat_pond'] = df.bs_lat * df.rssi_reshape
    df['bs_lng_pond'] = df.bs_lng * df.rssi_reshape
    BCW_lat = df.groupby('messid').bs_lat_pond.sum()/df.groupby('messid').rssi_reshape.sum()
    BCW_lat.name='BCW_lat'
    BCW_lng = df.groupby('messid').bs_lng_pond.sum()/df.groupby('messid').rssi_reshape.sum()
    BCW_lng.name='BCW_lng'

    #Pour le barycentre ajout min , max + mean 

    BC_lat = df.groupby('messid').agg(['mean', 'min', 'max'])[['bs_lat']]
    BC_lat.columns = BC_lat.columns.droplevel()

    BC_lng = df.groupby('messid').agg(['mean', 'min', 'max'])[['bs_lng']]
    BC_lng.columns = BC_lng.columns.droplevel()

    dev_lat =df.groupby(['did','messid']).agg(['mean', 'min', 'max'])[['bs_lat']].reset_index()
    dev_lat.columns = dev_lat.columns.droplevel()
    dev_lat.columns= ['did','messid','bs_l_did_mean', 'bs_l_did_min', 'bs_l_did_max']
    dev_lat=dev_lat.drop('did',axis=1)

    dev_lng =df.groupby(['did','messid']).agg(['mean', 'min', 'max'])[['bs_lng']].reset_index()
    dev_lng.columns = dev_lng.columns.droplevel()
    dev_lng.columns= ['did','messid','bs_L_did_mean', 'bs_L_did_min', 'bs_L_did_max']
    dev_lng=dev_lng.drop('did',axis=1)

    #On fait apparaitre une colonne contenant le messid pour la jointure

    df_feat = df_feat.reset_index()
    df_feat.rename(columns={'index':'messid'}, inplace=True)

    df_feat=df_feat.join(BCW_lat, on ='messid',how='left')
    df_feat=df_feat.join(BCW_lng, on ='messid',how='left')

    df_feat= pd.merge(df_feat,BC_lat,on='messid')
    df_feat= pd.merge(df_feat,BC_lng,on='messid')

    df_feat= pd.merge(df_feat,dev_lat,on='messid')
    df_feat= pd.merge(df_feat,dev_lng,on='messid')

    #On remet le messid dans l'index
    df_feat.set_index('messid',inplace=True)
    
    return df_feat, id_list

# %%
df_feat, id_list=feat_mat_const(X_train, listOfBs)

y_full = ground_truth_const(X_train, pos_train, id_list)
y_full.shape,df_feat.shape
# Out:
# ((6068, 3), (6068, 273))

# %%
# %%time
"""Cette celluel tourne pendant 2h !!!!!"""
"""Le résultat est stocké en pickle voir plus bas"""


#Code produit ensemble donc tu peux copier bêtement
Models={}
df_temp = df_feat[df_feat.columns[:-14]] #Ici on récupère la matrice df_feat sans columns supplémentaire
#Pour chaque base
for idx,base in enumerate(df_temp.columns):
    print(f"Base : {base}")
    
    #Prod de la sous matrice df_feat (lié à la base)
    df_feat_reduce=df_temp[df_temp[base]!=0]
    print(f"Nb message : {df_feat_reduce.shape[0]}")
    
    #On ne produit pas de modèle pour les bases non vu dans le train
    if df_feat_reduce.shape[0] :
        y=[];X=[]
        #On parcours tous les messages identifiés à une base
        for i,k in enumerate(df_feat_reduce.index):
            for j in df_temp.columns: #Je parcours toutes les bases et construit la matrice 259x259
                #print("tip")
                X.append(abs(df_temp.loc[k,j]-df_temp.loc[k,df_temp.columns].values))
                y.append(vincenty(base_coord.loc[j],msg_coord.loc[k]))
                #print("top")
        y=np.array(y)
        X=np.array(X)
        #On produit un modèle pour la base en question on note également l'indice de la base 
        model = xgb.XGBRegressor().fit(X,y);
        Models[base] = [idx,model]
        
        """ce bout de code ne sert QUE a vérifier si la méthode est bonne mais n'est pas nécessaire"""

        y_pred= Models[base][1].predict(X)
        #Calcul de le MAE
        sol=[]
        for j in range(y_pred.shape[0]//size):
            sol.append(y_pred[j*size:(j+1)*size][Models[base][0]])
        a =np.array(sol)
        b = X_train[X_train.bsid == base].dist.values 
        
        print(f"MAE de la base : {base} : {(np.abs(a-b)).mean()}")

    else :
        print(f"Base {base} en échec")
# Out:
# Base : 879
# Nb message : 1
# MAE de la base : 879 : 0.0030374271240241058
# Base : 911
# Nb message : 1
# MAE de la base : 911 : 0.0012908613281261694
# Base : 921
# Nb message : 1
# MAE de la base : 921 : 0.00010188110351805335
# Base : 944
# Nb message : 3
# MAE de la base : 944 : 0.0005513832193990709
# Base : 980
# Nb message : 8
# MAE de la base : 980 : 0.006038962215423438
# Base : 1012
# Nb message : 85
# MAE de la base : 1012 : 0.22651944486512576
# Base : 1086
# Nb message : 67
# MAE de la base : 1086 : 2.8489129506262025
# Base : 1092
# Nb message : 32
# MAE de la base : 1092 : 1.2256982178645135
# Base : 1120
# Nb message : 1
# MAE de la base : 1120 : 0.00043947338867411645
# Base : 1131
# Nb message : 0
# Base 1131 en échec
# Base : 1148
# Nb message : 2
# MAE de la base : 1148 : 0.0005229919433595853
# Base : 1156
# Nb message : 1
# MAE de la base : 1156 : 166.88552357958986
# Base : 1187
# Nb message : 2
# MAE de la base : 1187 : 70.96475746295167
# Base : 1226
# Nb message : 2
# MAE de la base : 1226 : 2.526835102905274
# Base : 1229
# Nb message : 16
# MAE de la base : 1229 : 0.5589162200393677
# Base : 1235
# Nb message : 2
# MAE de la base : 1235 : 13.081887046447754
# Base : 1237
# Nb message : 1
# MAE de la base : 1237 : 49.76558742041016
# Base : 1264
# Nb message : 320
# MAE de la base : 1264 : 1.2073661200415164
# Base : 1266
# Nb message : 3
# MAE de la base : 1266 : 0.45518771024576904
# Base : 1268
# Nb message : 58
# MAE de la base : 1268 : 0.9941556572344549
# Base : 1292
# Nb message : 6
# MAE de la base : 1292 : 8.870387662719725
# Base : 1334
# Nb message : 12
# MAE de la base : 1334 : 0.024102432971954284
# Base : 1344
# Nb message : 184
# MAE de la base : 1344 : 0.7357184166989947
# Base : 1432
# Nb message : 1
# MAE de la base : 1432 : 0.0006357103271481535
# Base : 1443
# Nb message : 1
# MAE de la base : 1443 : 0.0013034394531246107
# Base : 1447
# Nb message : 2
# MAE de la base : 1447 : 11.23722824926758
# Base : 1463
# Nb message : 2
# MAE de la base : 1463 : 0.0008984895019521488
# Base : 1476
# Nb message : 174
# MAE de la base : 1476 : 0.7719926938099476
# Base : 1526
# Nb message : 11
# MAE de la base : 1526 : 0.14422511288174678
# Base : 1530
# Nb message : 8
# MAE de la base : 1530 : 0.0010266409606924931
# Base : 1534
# Nb message : 1
# MAE de la base : 1534 : 0.0011657824707000941
# Base : 1581
# Nb message : 2
# MAE de la base : 1581 : 3.9775417047729498
# Base : 1594
# Nb message : 290
# MAE de la base : 1594 : 1.0102545153007476
# Base : 1661
# Nb message : 160
# MAE de la base : 1661 : 1.4222147490457295
# Base : 1730
# Nb message : 1
# MAE de la base : 1730 : 0.001158753417968228
# Base : 1741
# Nb message : 428
# MAE de la base : 1741 : 0.41010764056711324
# Base : 1743
# Nb message : 169
# MAE de la base : 1743 : 0.7863892052268981
# Base : 1772
# Nb message : 121
# MAE de la base : 1772 : 1.0586983834289994
# Base : 1796
# Nb message : 249
# MAE de la base : 1796 : 1.177864402235713
# Base : 1826
# Nb message : 9
# MAE de la base : 1826 : 1.7031771383955214
# Base : 1828
# Nb message : 3
# MAE de la base : 1828 : 0.0012656317545562956
# Base : 1838
# Nb message : 1
# MAE de la base : 1838 : 0.0011445836181636082
# Base : 1852
# Nb message : 3
# MAE de la base : 1852 : 0.00043324627685296474
# Base : 1854
# Nb message : 27
# MAE de la base : 1854 : 1.661145597132365
# Base : 1859
# Nb message : 987
# MAE de la base : 1859 : 1.6933898743999336
# Base : 1872
# Nb message : 214
# MAE de la base : 1872 : 2.0038184186794243
# Base : 1878
# Nb message : 1128
# MAE de la base : 1878 : 1.2347696432416286
# Base : 1971
# Nb message : 2
# MAE de la base : 1971 : 2.275677940917971
# Base : 1987
# Nb message : 298
# MAE de la base : 1987 : 0.3857384124570925
# Base : 1988
# Nb message : 307
# MAE de la base : 1988 : 2.4195977958185155
# Base : 1994
# Nb message : 212
# MAE de la base : 1994 : 0.40234903349462825
# Base : 1996
# Nb message : 392
# MAE de la base : 1996 : 0.5766821476690697
# Base : 2189
# Nb message : 1073
# MAE de la base : 2189 : 0.7691351791973674
# Base : 2293
# Nb message : 2
# MAE de la base : 2293 : 1.1852080887451173
# Base : 2605
# Nb message : 549
# MAE de la base : 2605 : 1.3444041720291442
# Base : 2610
# Nb message : 459
# MAE de la base : 2610 : 1.0239862402702449
# Base : 2611
# Nb message : 1
# MAE de la base : 2611 : 0.03674131176757811
# Base : 2617
# Nb message : 673
# MAE de la base : 2617 : 0.7128207980905223
# Base : 2693
# Nb message : 4
# MAE de la base : 2693 : 2.206032894371032
# Base : 2707
# Nb message : 191
# MAE de la base : 2707 : 0.6660098041742534
# Base : 2731
# Nb message : 371
# MAE de la base : 2731 : 0.5945142846143779
# Base : 2737
# Nb message : 27
# MAE de la base : 2737 : 1.5337363406191225
# Base : 2762
# Nb message : 25
# MAE de la base : 2762 : 5.299713055714111
# Base : 2765
# Nb message : 1
# MAE de la base : 2765 : 0.0008150666503894399
# Base : 2766
# Nb message : 17
# MAE de la base : 2766 : 0.0005998693192426858
# Base : 2768
# Nb message : 47
# MAE de la base : 2768 : 2.430418682363307
# Base : 2770
# Nb message : 1
# MAE de la base : 2770 : 0.0021030061035176573
# Base : 2775
# Nb message : 29
# MAE de la base : 2775 : 0.28535764335790187
# Base : 2776
# Nb message : 47
# MAE de la base : 2776 : 1.2091706496802799
# Base : 2780
# Nb message : 8
# MAE de la base : 2780 : 4.005179506469727
# Base : 2784
# Nb message : 100
# MAE de la base : 2784 : 0.6980304364612959
# Base : 2790
# Nb message : 401
# MAE de la base : 2790 : 1.1669018056815947
# Base : 2799
# Nb message : 394
# MAE de la base : 2799 : 1.626737286020889
# Base : 2800
# Nb message : 35
# MAE de la base : 2800 : 0.06406606501116455
# Base : 2803
# Nb message : 32
# MAE de la base : 2803 : 0.12160055639648704
# Base : 2808
# Nb message : 22
# MAE de la base : 2808 : 0.12136276154119101
# Base : 2831
# Nb message : 372
# MAE de la base : 2831 : 0.7943804384665132
# Base : 2836
# Nb message : 1
# MAE de la base : 2836 : 0.001275065185545543
# Base : 2837
# Nb message : 17
# MAE de la base : 2837 : 0.763218534316119
# Base : 2841
# Nb message : 136
# MAE de la base : 2841 : 0.7520508299691256
# Base : 2842
# Nb message : 37
# MAE de la base : 2842 : 2.76232391285087
# Base : 2845
# Nb message : 3
# MAE de la base : 2845 : 8.355075947591146
# Base : 2846
# Nb message : 409
# MAE de la base : 2846 : 1.5656182499178488
# Base : 2849
# Nb message : 2
# MAE de la base : 2849 : 17.66169105566406
# Base : 2855
# Nb message : 1
# MAE de la base : 2855 : 0.001082687744137445
# Base : 2862
# Nb message : 169
# MAE de la base : 2862 : 0.7456782243087137
# Base : 2943
# Nb message : 90
# MAE de la base : 2943 : 1.5532949066882664
# Base : 2945
# Nb message : 1
# MAE de la base : 2945 : 16.34361239916992
# Base : 2999
# Nb message : 606
# MAE de la base : 2999 : 0.7631480161561085
# Base : 3025
# Nb message : 564
# MAE de la base : 3025 : 1.4084994670469135
# Base : 3034
# Nb message : 0
# Base 3034 en échec
# Base : 3041
# Nb message : 2
# MAE de la base : 3041 : 10.132234882751465
# Base : 3051
# Nb message : 249
# MAE de la base : 3051 : 0.26913590301771045
# Base : 3256
# Nb message : 70
# MAE de la base : 3256 : 2.977603994757516
# Base : 3357
# Nb message : 206
# MAE de la base : 3357 : 0.9020248032896911
# Base : 3378
# Nb message : 92
# MAE de la base : 3378 : 1.0024999912589296
# Base : 3385
# Nb message : 1
# MAE de la base : 3385 : 0.00011724926757850085
# Base : 3386
# Nb message : 190
# MAE de la base : 3386 : 1.2394184651571574
# Base : 3389
# Nb message : 24
# MAE de la base : 3389 : 0.8312322169841132
# Base : 3402
# Nb message : 64
# MAE de la base : 3402 : 0.747773262082696
# Base : 3403
# Nb message : 264
# MAE de la base : 3403 : 1.3572231699334636
# Base : 3410
# Nb message : 574
# MAE de la base : 3410 : 1.1897538422926128
# Base : 3412
# Nb message : 538
# MAE de la base : 3412 : 1.078552273515978
# Base : 3414
# Nb message : 269
# MAE de la base : 3414 : 1.1990736652087384
# Base : 3415
# Nb message : 111
# MAE de la base : 3415 : 1.194279156101674
# Base : 3500
# Nb message : 261
# MAE de la base : 3500 : 1.2717556449441727
# Base : 3501
# Nb message : 10
# MAE de la base : 3501 : 0.395779618749998
# Base : 3515
# Nb message : 1
# MAE de la base : 3515 : 0.0004118435058586556
# Base : 3526
# Nb message : 242
# MAE de la base : 3526 : 1.414006334563405
# Base : 3527
# Nb message : 315
# MAE de la base : 3527 : 0.3789045884165506
# Base : 3529
# Nb message : 194
# MAE de la base : 3529 : 1.3437402220866606
# Base : 3535
# Nb message : 9
# MAE de la base : 3535 : 2.342976624186198
# Base : 3536
# Nb message : 47
# MAE de la base : 3536 : 1.3533449042364893
# Base : 3538
# Nb message : 541
# MAE de la base : 3538 : 0.60180975618434
# Base : 3544
# Nb message : 23
# MAE de la base : 3544 : 0.20587049523262343
# Base : 3545
# Nb message : 370
# MAE de la base : 3545 : 1.353017118405904
# Base : 3546
# Nb message : 22
# MAE de la base : 3546 : 0.2574837415013747
# Base : 3547
# Nb message : 417
# MAE de la base : 3547 : 1.3998327611196324
# Base : 3548
# Nb message : 570
# MAE de la base : 3548 : 0.9757865115255088
# Base : 3549
# Nb message : 1
# MAE de la base : 3549 : 70.62915384252929
# Base : 3553
# Nb message : 58
# MAE de la base : 3553 : 1.2787806912234077
# Base : 3554
# Nb message : 129
# MAE de la base : 3554 : 3.4355494994673617
# Base : 3555
# Nb message : 44
# MAE de la base : 3555 : 0.5557488635976965
# Base : 3556
# Nb message : 472
# MAE de la base : 3556 : 0.6172065785682838
# Base : 3558
# Nb message : 205
# MAE de la base : 3558 : 1.1943030167541224
# Base : 3559
# Nb message : 165
# MAE de la base : 3559 : 1.113034111408257
# Base : 3562
# Nb message : 866
# MAE de la base : 3562 : 0.9178459159027192
# Base : 3563
# Nb message : 195
# MAE de la base : 3563 : 1.7237384178297779
# Base : 3565
# Nb message : 265
# MAE de la base : 3565 : 2.3742524304909183
# Base : 3568
# Nb message : 43
# MAE de la base : 3568 : 3.295331692598565
# Base : 3569
# Nb message : 232
# MAE de la base : 3569 : 1.757714909971632
# Base : 3570
# Nb message : 355
# MAE de la base : 3570 : 1.0365311124904792
# Base : 3571
# Nb message : 132
# MAE de la base : 3571 : 0.10369230863351712
# Base : 3572
# Nb message : 1
# MAE de la base : 3572 : 5.301615703125002
# Base : 3574
# Nb message : 172
# MAE de la base : 3574 : 0.9143196171192015
# Base : 3575
# Nb message : 14
# MAE de la base : 3575 : 0.6301450586526055
# Base : 3576
# Nb message : 165
# MAE de la base : 3576 : 0.8792024036329791
# Base : 3577
# Nb message : 2
# MAE de la base : 3577 : 2.43043534338379
# Base : 3578
# Nb message : 437
# MAE de la base : 3578 : 1.2963572509984205
# Base : 3579
# Nb message : 437
# MAE de la base : 3579 : 0.8657669852493163
# Base : 3581
# Nb message : 343
# MAE de la base : 3581 : 1.1391684189143831
# Base : 3613
# Nb message : 286
# MAE de la base : 3613 : 0.5617108593620354
# Base : 3629
# Nb message : 3
# MAE de la base : 3629 : 0.0009679741719565982
# Base : 3630
# Nb message : 23
# MAE de la base : 3630 : 0.045524941321332335
# Base : 3646
# Nb message : 1
# MAE de la base : 3646 : 0.03794533691406343
# Base : 3828
# Nb message : 0
# Base 3828 en échec
# Base : 3835
# Nb message : 26
# MAE de la base : 3835 : 0.29447963968768487
# Base : 3846
# Nb message : 376
# MAE de la base : 3846 : 0.8559041909284388
# Base : 3848
# Nb message : 29
# MAE de la base : 3848 : 0.0010579806034480372
# Base : 3907
# Nb message : 16
# MAE de la base : 3907 : 0.3333665007963179
# Base : 3915
# Nb message : 2
# MAE de la base : 3915 : 0.0006002175292962875
# Base : 3933
# Nb message : 21
# MAE de la base : 3933 : 0.11686428543526431
# Base : 3983
# Nb message : 4
# MAE de la base : 3983 : 4.255190315963745
# Base : 4013
# Nb message : 4
# MAE de la base : 4013 : 0.5231153325195237
# Base : 4024
# Nb message : 219
# MAE de la base : 4024 : 0.1675558604333564
# Base : 4047
# Nb message : 5
# MAE de la base : 4047 : 4.691240124765015
# Base : 4049
# Nb message : 4
# MAE de la base : 4049 : 1.50987445904541
# Base : 4055
# Nb message : 20
# MAE de la base : 4055 : 1.627698343243027
# Base : 4056
# Nb message : 410
# MAE de la base : 4056 : 1.1007387704365474
# Base : 4058
# Nb message : 672
# MAE de la base : 4058 : 0.9004670419118632
# Base : 4059
# Nb message : 440
# MAE de la base : 4059 : 0.8434585609006535
# Base : 4060
# Nb message : 3
# MAE de la base : 4060 : 1.023425697479248
# Base : 4064
# Nb message : 171
# MAE de la base : 4064 : 4.0016573015133154
# Base : 4065
# Nb message : 9
# MAE de la base : 4065 : 2.3786100360717777
# Base : 4073
# Nb message : 2
# MAE de la base : 4073 : 3.4283912588195795
# Base : 4078
# Nb message : 159
# MAE de la base : 4078 : 0.9359495882305409
# Base : 4088
# Nb message : 6
# MAE de la base : 4088 : 2.541334748179118
# Base : 4092
# Nb message : 43
# MAE de la base : 4092 : 0.9592842396850586
# Base : 4105
# Nb message : 13
# MAE de la base : 4105 : 7.469835327434833
# Base : 4123
# Nb message : 1
# MAE de la base : 4123 : 0.00023559625244118365
# Base : 4129
# Nb message : 216
# MAE de la base : 4129 : 0.5172322624740248
# Base : 4147
# Nb message : 153
# MAE de la base : 4147 : 1.7041759586865795
# Base : 4148
# Nb message : 31
# MAE de la base : 4148 : 0.20485258672455828
# Base : 4156
# Nb message : 127
# MAE de la base : 4156 : 0.45327331773219404
# Base : 4157
# Nb message : 688
# MAE de la base : 4157 : 0.5065735279992831
# Base : 4205
# Nb message : 76
# MAE de la base : 4205 : 8.203498950775149
# Base : 4244
# Nb message : 147
# MAE de la base : 4244 : 0.5446159524900313
# Base : 4646
# Nb message : 27
# MAE de la base : 4646 : 1.9119672860514325
# Base : 4790
# Nb message : 316
# MAE de la base : 4790 : 0.5391212370211204
# Base : 4813
# Nb message : 1
# MAE de la base : 4813 : 12.308444305175783
# Base : 4819
# Nb message : 96
# MAE de la base : 4819 : 2.3772472417940693
# Base : 4959
# Nb message : 1
# MAE de la base : 4959 : 20.27848617834473
# Base : 4966
# Nb message : 110
# MAE de la base : 4966 : 0.336633200636361
# Base : 4987
# Nb message : 147
# MAE de la base : 4987 : 1.1680391739693465
# Base : 4993
# Nb message : 488
# MAE de la base : 4993 : 0.8702707384886663
# Base : 4996
# Nb message : 9
# MAE de la base : 4996 : 0.0006374957851834494
# Base : 7248
# Nb message : 9
# MAE de la base : 7248 : 2.1468728226364986
# Base : 7378
# Nb message : 1
# MAE de la base : 7378 : 56.528768125
# Base : 7382
# Nb message : 420
# MAE de la base : 7382 : 1.131515143293433
# Base : 7435
# Nb message : 7
# MAE de la base : 7435 : 1.3663751373487194
# Base : 7456
# Nb message : 430
# MAE de la base : 7456 : 1.2200736293507732
# Base : 7490
# Nb message : 3
# MAE de la base : 7490 : 0.0006506071370443086
# Base : 7508
# Nb message : 1
# MAE de la base : 7508 : 0.0014080585937676915
# Base : 7628
# Nb message : 1
# MAE de la base : 7628 : 16.392861600830074
# Base : 7655
# Nb message : 1
# MAE de la base : 7655 : 0.0009846989746087331
# Base : 7673
# Nb message : 1
# MAE de la base : 7673 : 13.090960780639648
# Base : 7692
# Nb message : 264
# MAE de la base : 7692 : 0.4473912409899163
# Base : 7726
# Nb message : 87
# MAE de la base : 7726 : 0.3160999944696536
# Base : 7738
# Nb message : 210
# MAE de la base : 7738 : 0.6859890266544886
# Base : 7789
# Nb message : 100
# MAE de la base : 7789 : 0.5368798336392212
# Base : 7807
# Nb message : 34
# MAE de la base : 7807 : 0.2654200007485782
# Base : 7849
# Nb message : 6
# MAE de la base : 7849 : 2.2719738327840164
# Base : 7857
# Nb message : 7
# MAE de la base : 7857 : 0.0029008451320094203
# Base : 7972
# Nb message : 2
# MAE de la base : 7972 : 0.0013829252777095569
# Base : 7986
# Nb message : 7
# MAE de la base : 7986 : 0.013776821672712864
# Base : 8079
# Nb message : 2
# MAE de la base : 8079 : 7.191229278198241
# Base : 8082
# Nb message : 56
# MAE de la base : 8082 : 4.054013122397286
# Base : 8168
# Nb message : 0
# Base 8168 en échec
# Base : 8226
# Nb message : 1
# MAE de la base : 8226 : 5.302997296874999
# Base : 8242
# Nb message : 1
# MAE de la base : 8242 : 23.765798703369143
# Base : 8245
# Nb message : 413
# MAE de la base : 8245 : 0.947235517608235
# Base : 8351
# Nb message : 103
# MAE de la base : 8351 : 1.2640754286521245
# Base : 8352
# Nb message : 368
# MAE de la base : 8352 : 0.8259360257118165
# Base : 8355
# Nb message : 480
# MAE de la base : 8355 : 0.9394334842114608
# Base : 8356
# Nb message : 595
# MAE de la base : 8356 : 1.185725123859008
# Base : 8364
# Nb message : 280
# MAE de la base : 8364 : 1.206580824488449
# Base : 8368
# Nb message : 29
# MAE de la base : 8368 : 5.820218186386635
# Base : 8370
# Nb message : 251
# MAE de la base : 8370 : 1.0030851981882347
# Base : 8371
# Nb message : 8
# MAE de la base : 8371 : 0.864102089637756
# Base : 8384
# Nb message : 22
# MAE de la base : 8384 : 0.3875473497886659
# Base : 8390
# Nb message : 1
# MAE de la base : 8390 : 0.0005268780517582172
# Base : 8392
# Nb message : 1
# MAE de la base : 8392 : 0.0008333575439465335
# Base : 8397
# Nb message : 444
# MAE de la base : 8397 : 0.9127000601920428
# Base : 8401
# Nb message : 1
# MAE de la base : 8401 : 0.0003540263671908406
# Base : 8405
# Nb message : 1
# MAE de la base : 8405 : 0.0010065322265688792
# Base : 8426
# Nb message : 73
# MAE de la base : 8426 : 1.1430937267218813
# Base : 8437
# Nb message : 384
# MAE de la base : 8437 : 0.9813114252681069
# Base : 8442
# Nb message : 1
# MAE de la base : 8442 : 0.008252183105469157
# Base : 8446
# Nb message : 888
# MAE de la base : 8446 : 0.911384176491823
# Base : 8449
# Nb message : 72
# MAE de la base : 8449 : 0.7217824836519029
# Base : 8450
# Nb message : 38
# MAE de la base : 8450 : 0.14583077969799538
# Base : 8451
# Nb message : 193
# MAE de la base : 8451 : 1.257401573374348
# Base : 8452
# Nb message : 95
# MAE de la base : 8452 : 1.2277945741795588
# Base : 8453
# Nb message : 49
# MAE de la base : 8453 : 0.12588848970459918
# Base : 8457
# Nb message : 40
# MAE de la base : 8457 : 0.1317774392385483
# Base : 8470
# Nb message : 481
# MAE de la base : 8470 : 0.7717079154359338
# Base : 8471
# Nb message : 13
# MAE de la base : 8471 : 1.190384750042255
# Base : 8472
# Nb message : 284
# MAE de la base : 8472 : 1.2804369159983247
# Base : 8473
# Nb message : 112
# MAE de la base : 8473 : 0.38380771483666554
# Base : 8474
# Nb message : 416
# MAE de la base : 8474 : 0.8220770973647511
# Base : 8475
# Nb message : 322
# MAE de la base : 8475 : 1.0439339584213863
# Base : 8495
# Nb message : 41
# MAE de la base : 8495 : 0.42933625952734583
# Base : 8509
# Nb message : 156
# MAE de la base : 8509 : 0.9093954502197047
# Base : 8560
# Nb message : 116
# MAE de la base : 8560 : 1.9230704583782001
# Base : 8746
# Nb message : 74
# MAE de la base : 8746 : 0.6330339003767066
# Base : 8747
# Nb message : 71
# MAE de la base : 8747 : 1.332871270547786
# Base : 9783
# Nb message : 0
# Base 9783 en échec
# Base : 9784
# Nb message : 1
# MAE de la base : 9784 : 0.0008333575439465335
# Base : 9899
# Nb message : 527
# MAE de la base : 9899 : 0.8351767779178692
# Base : 9936
# Nb message : 0
# Base 9936 en échec
# Base : 9941
# Nb message : 0
# Base 9941 en échec
# Base : 9949
# Nb message : 0
# Base 9949 en échec
# Base : 10134
# Nb message : 8
# MAE de la base : 10134 : 1.4405564480285644
# Base : 10148
# Nb message : 2
# MAE de la base : 10148 : 36.22783406610107
# Base : 10151
# Nb message : 333
# MAE de la base : 10151 : 0.7735601226946285
# Base : 10162
# Nb message : 597
# MAE de la base : 10162 : 0.7897973703237563
# Base : 10999
# Nb message : 1
# MAE de la base : 10999 : 6.336540148681641
# Base : 11007
# Nb message : 275
# MAE de la base : 11007 : 0.6621534751801091
# Base : 11951
# Nb message : 1
# MAE de la base : 11951 : 0.0013223623046876298
# Wall time: 2h 16min 53s

# %%
"""NE PAS RUNNER"""
with open (f"Models.pkl","wb") as fp :
    pickle.dump(Models, fp)

# %%
""" Runner cette cellule pour charger les Models"""
with open (f"Models.pkl","rb") as fp :
    Models = pickle.load(fp)

# %% [markdown]
# # Prédiction sur le Train pour qualifier la solution et le fit

# %%
df=X_train
df_feat, id_list=feat_mat_const(df, listOfBs)
df_temp = df_feat[df_feat.columns[:-14]]
df_group = df.groupby("messid", as_index=False)
nb_mess = len(df.messid.unique())
df_feat_new = pd.DataFrame(np.zeros((nb_mess, len(listOfBs))), columns=listOfBs, index=df.messid.unique())

# %%
# %%time
for idx,base in enumerate(df_temp.columns):
    print(f"Base : {base}")
    #Prod de la sous matrice df_feat (lié à la base)
    df_feat_reduce=df_temp[df_temp[base]!=0]
    print(f"Nb message : {df_feat_reduce.shape[0]}")
    if df_feat_reduce.shape[0]:
        if Models.get(base,False) :
            X=[]
            #On parcours tous les messages identifié à une base
            for i,k in enumerate(df_feat_reduce.index):
                for j in df_temp.columns: #Je parcours toutes les bases et construit la matrice 259x259
                    X.append(abs(df_temp.loc[k,j]-df_temp.loc[k,df_temp.columns]).values)
            X=np.array(X)
            y= Models[base][1].predict(X)
            sol=[]
            for j in range(y.shape[0]//size):
                sol.append(y[j*size:(j+1)*size][Models[base][0]])
            df_feat_new.loc[df_feat_reduce.index.values,base]=np.array(sol)
        else:
            print(f"Base non modélisée {base}")
            """Ici on pourrait prévoire un amélioration qui une fois le message prédit on construit le modèle"""
    else :
        print(f"Base sans message {base}")
# Out:
# Base : 879
# Nb message : 1
# Base : 911
# Nb message : 1
# Base : 921
# Nb message : 1
# Base : 944
# Nb message : 3
# Base : 980
# Nb message : 8
# Base : 1012
# Nb message : 85
# Base : 1086
# Nb message : 67
# Base : 1092
# Nb message : 32
# Base : 1120
# Nb message : 1
# Base : 1131
# Nb message : 0
# Base sans message 1131
# Base : 1148
# Nb message : 2
# Base : 1156
# Nb message : 1
# Base : 1187
# Nb message : 2
# Base : 1226
# Nb message : 2
# Base : 1229
# Nb message : 16
# Base : 1235
# Nb message : 2
# Base : 1237
# Nb message : 1
# Base : 1264
# Nb message : 320
# Base : 1266
# Nb message : 3
# Base : 1268
# Nb message : 58
# Base : 1292
# Nb message : 6
# Base : 1334
# Nb message : 12
# Base : 1344
# Nb message : 184
# Base : 1432
# Nb message : 1
# Base : 1443
# Nb message : 1
# Base : 1447
# Nb message : 2
# Base : 1463
# Nb message : 2
# Base : 1476
# Nb message : 174
# Base : 1526
# Nb message : 11
# Base : 1530
# Nb message : 8
# Base : 1534
# Nb message : 1
# Base : 1581
# Nb message : 2
# Base : 1594
# Nb message : 290
# Base : 1661
# Nb message : 160
# Base : 1730
# Nb message : 1
# Base : 1741
# Nb message : 428
# Base : 1743
# Nb message : 169
# Base : 1772
# Nb message : 121
# Base : 1796
# Nb message : 249
# Base : 1826
# Nb message : 9
# Base : 1828
# Nb message : 3
# Base : 1838
# Nb message : 1
# Base : 1852
# Nb message : 3
# Base : 1854
# Nb message : 27
# Base : 1859
# Nb message : 987
# Base : 1872
# Nb message : 214
# Base : 1878
# Nb message : 1128
# Base : 1971
# Nb message : 2
# Base : 1987
# Nb message : 298
# Base : 1988
# Nb message : 307
# Base : 1994
# Nb message : 212
# Base : 1996
# Nb message : 392
# Base : 2189
# Nb message : 1073
# Base : 2293
# Nb message : 2
# Base : 2605
# Nb message : 549
# Base : 2610
# Nb message : 459
# Base : 2611
# Nb message : 1
# Base : 2617
# Nb message : 673
# Base : 2693
# Nb message : 4
# Base : 2707
# Nb message : 191
# Base : 2731
# Nb message : 371
# Base : 2737
# Nb message : 27
# Base : 2762
# Nb message : 25
# Base : 2765
# Nb message : 1
# Base : 2766
# Nb message : 17
# Base : 2768
# Nb message : 47
# Base : 2770
# Nb message : 1
# Base : 2775
# Nb message : 29
# Base : 2776
# Nb message : 47
# Base : 2780
# Nb message : 8
# Base : 2784
# Nb message : 100
# Base : 2790
# Nb message : 401
# Base : 2799
# Nb message : 394
# Base : 2800
# Nb message : 35
# Base : 2803
# Nb message : 32
# Base : 2808
# Nb message : 22
# Base : 2831
# Nb message : 372
# Base : 2836
# Nb message : 1
# Base : 2837
# Nb message : 17
# Base : 2841
# Nb message : 136
# Base : 2842
# Nb message : 37
# Base : 2845
# Nb message : 3
# Base : 2846
# Nb message : 409
# Base : 2849
# Nb message : 2
# Base : 2855
# Nb message : 1
# Base : 2862
# Nb message : 169
# Base : 2943
# Nb message : 90
# Base : 2945
# Nb message : 1
# Base : 2999
# Nb message : 606
# Base : 3025
# Nb message : 564
# Base : 3034
# Nb message : 0
# Base sans message 3034
# Base : 3041
# Nb message : 2
# Base : 3051
# Nb message : 249
# Base : 3256
# Nb message : 70
# Base : 3357
# Nb message : 206
# Base : 3378
# Nb message : 92
# Base : 3385
# Nb message : 1
# Base : 3386
# Nb message : 190
# Base : 3389
# Nb message : 24
# Base : 3402
# Nb message : 64
# Base : 3403
# Nb message : 264
# Base : 3410
# Nb message : 574
# Base : 3412
# Nb message : 538
# Base : 3414
# Nb message : 269
# Base : 3415
# Nb message : 111
# Base : 3500
# Nb message : 261
# Base : 3501
# Nb message : 10
# Base : 3515
# Nb message : 1
# Base : 3526
# Nb message : 242
# Base : 3527
# Nb message : 315
# Base : 3529
# Nb message : 194
# Base : 3535
# Nb message : 9
# Base : 3536
# Nb message : 47
# Base : 3538
# Nb message : 541
# Base : 3544
# Nb message : 23
# Base : 3545
# Nb message : 370
# Base : 3546
# Nb message : 22
# Base : 3547
# Nb message : 417
# Base : 3548
# Nb message : 570
# Base : 3549
# Nb message : 1
# Base : 3553
# Nb message : 58
# Base : 3554
# Nb message : 129
# Base : 3555
# Nb message : 44
# Base : 3556
# Nb message : 472
# Base : 3558
# Nb message : 205
# Base : 3559
# Nb message : 165
# Base : 3562
# Nb message : 866
# Base : 3563
# Nb message : 195
# Base : 3565
# Nb message : 265
# Base : 3568
# Nb message : 43
# Base : 3569
# Nb message : 232
# Base : 3570
# Nb message : 355
# Base : 3571
# Nb message : 132
# Base : 3572
# Nb message : 1
# Base : 3574
# Nb message : 172
# Base : 3575
# Nb message : 14
# Base : 3576
# Nb message : 165
# Base : 3577
# Nb message : 2
# Base : 3578
# Nb message : 437
# Base : 3579
# Nb message : 437
# Base : 3581
# Nb message : 343
# Base : 3613
# Nb message : 286
# Base : 3629
# Nb message : 3
# Base : 3630
# Nb message : 23
# Base : 3646
# Nb message : 1
# Base : 3828
# Nb message : 0
# Base sans message 3828
# Base : 3835
# Nb message : 26
# Base : 3846
# Nb message : 376
# Base : 3848
# Nb message : 29
# Base : 3907
# Nb message : 16
# Base : 3915
# Nb message : 2
# Base : 3933
# Nb message : 21
# Base : 3983
# Nb message : 4
# Base : 4013
# Nb message : 4
# Base : 4024
# Nb message : 219
# Base : 4047
# Nb message : 5
# Base : 4049
# Nb message : 4
# Base : 4055
# Nb message : 20
# Base : 4056
# Nb message : 410
# Base : 4058
# Nb message : 672
# Base : 4059
# Nb message : 440
# Base : 4060
# Nb message : 3
# Base : 4064
# Nb message : 171
# Base : 4065
# Nb message : 9
# Base : 4073
# Nb message : 2
# Base : 4078
# Nb message : 159
# Base : 4088
# Nb message : 6
# Base : 4092
# Nb message : 43
# Base : 4105
# Nb message : 13
# Base : 4123
# Nb message : 1
# Base : 4129
# Nb message : 216
# Base : 4147
# Nb message : 153
# Base : 4148
# Nb message : 31
# Base : 4156
# Nb message : 127
# Base : 4157
# Nb message : 688
# Base : 4205
# Nb message : 76
# Base : 4244
# Nb message : 147
# Base : 4646
# Nb message : 27
# Base : 4790
# Nb message : 316
# Base : 4813
# Nb message : 1
# Base : 4819
# Nb message : 96
# Base : 4959
# Nb message : 1
# Base : 4966
# Nb message : 110
# Base : 4987
# Nb message : 147
# Base : 4993
# Nb message : 488
# Base : 4996
# Nb message : 9
# Base : 7248
# Nb message : 9
# Base : 7378
# Nb message : 1
# Base : 7382
# Nb message : 420
# Base : 7435
# Nb message : 7
# Base : 7456
# Nb message : 430
# Base : 7490
# Nb message : 3
# Base : 7508
# Nb message : 1
# Base : 7628
# Nb message : 1
# Base : 7655
# Nb message : 1
# Base : 7673
# Nb message : 1
# Base : 7692
# Nb message : 264
# Base : 7726
# Nb message : 87
# Base : 7738
# Nb message : 210
# Base : 7789
# Nb message : 100
# Base : 7807
# Nb message : 34
# Base : 7849
# Nb message : 6
# Base : 7857
# Nb message : 7
# Base : 7972
# Nb message : 2
# Base : 7986
# Nb message : 7
# Base : 8079
# Nb message : 2
# Base : 8082
# Nb message : 56
# Base : 8168
# Nb message : 0
# Base sans message 8168
# Base : 8226
# Nb message : 1
# Base : 8242
# Nb message : 1
# Base : 8245
# Nb message : 413
# Base : 8351
# Nb message : 103
# Base : 8352
# Nb message : 368
# Base : 8355
# Nb message : 480
# Base : 8356
# Nb message : 595
# Base : 8364
# Nb message : 280
# Base : 8368
# Nb message : 29
# Base : 8370
# Nb message : 251
# Base : 8371
# Nb message : 8
# Base : 8384
# Nb message : 22
# Base : 8390
# Nb message : 1
# Base : 8392
# Nb message : 1
# Base : 8397
# Nb message : 444
# Base : 8401
# Nb message : 1
# Base : 8405
# Nb message : 1
# Base : 8426
# Nb message : 73
# Base : 8437
# Nb message : 384
# Base : 8442
# Nb message : 1
# Base : 8446
# Nb message : 888
# Base : 8449
# Nb message : 72
# Base : 8450
# Nb message : 38
# Base : 8451
# Nb message : 193
# Base : 8452
# Nb message : 95
# Base : 8453
# Nb message : 49
# Base : 8457
# Nb message : 40
# Base : 8470
# Nb message : 481
# Base : 8471
# Nb message : 13
# Base : 8472
# Nb message : 284
# Base : 8473
# Nb message : 112
# Base : 8474
# Nb message : 416
# Base : 8475
# Nb message : 322
# Base : 8495
# Nb message : 41
# Base : 8509
# Nb message : 156
# Base : 8560
# Nb message : 116
# Base : 8746
# Nb message : 74
# Base : 8747
# Nb message : 71
# Base : 9783
# Nb message : 0
# Base sans message 9783
# Base : 9784
# Nb message : 1
# Base : 9899
# Nb message : 527
# Base : 9936
# Nb message : 0
# Base sans message 9936
# Base : 9941
# Nb message : 0
# Base sans message 9941
# Base : 9949
# Nb message : 0
# Base sans message 9949
# Base : 10134
# Nb message : 8
# Base : 10148
# Nb message : 2
# Base : 10151
# Nb message : 333
# Base : 10162
# Nb message : 597
# Base : 10999
# Nb message : 1
# Base : 11007
# Nb message : 275
# Base : 11951
# Nb message : 1
# Wall time: 1h 33min 45s

# %%
#Je rajoute le calcul des barycente que l'on trouve dans le df_feat
df_feat_new_TRAIN = pd.merge(df_feat_new,df_feat[df_feat.columns[-14:]],right_index=True,left_index=True)

# %%
"""NE PAS RUNNER"""
with open (f"df_feat_new_TRAIN.pkl","wb") as fp :
    pickle.dump(df_feat_new_TRAIN, fp)

# %%
""" Runner cette cellule pour charger la df Feat du X_train"""
with open (f"df_feat_new_TRAIN.pkl","rb") as fp :
    df_feat_new_TRAIN = pickle.load(fp)

# %% [markdown]
# # Qualification avec les hypers paramètres trouvés

# %%
df_params = pd.read_csv("best_params.csv")

# %%
r1 = RandomForestRegressor(**get_hyperparameter('RandomForestRegressor', 'lng'))
r2 = GradientBoostingRegressor(**get_hyperparameter('GradientBoostingRegressor', 'lng'))
r3 = ExtraTreeRegressor(**get_hyperparameter('ExtraTreeRegressor', 'lng'))
r4 = xgb.XGBRegressor(**get_hyperparameter('XGBRegressor', 'lng'))
r5 = BaggingRegressor(**get_hyperparameter('BaggingRegressor', 'lng'))
Vr_lng = VotingRegressor(estimators=[('Et',r1),('Rf',r2),('Gb',r3),('Xg',r4),('Xdg',r5)])


r1 = RandomForestRegressor(**get_hyperparameter('RandomForestRegressor', 'lat'))
r2 = GradientBoostingRegressor(**get_hyperparameter('GradientBoostingRegressor', 'lat'))
r3 = ExtraTreeRegressor(**get_hyperparameter('ExtraTreeRegressor', 'lat'))
r4 = xgb.XGBRegressor(**get_hyperparameter('XGBRegressor', 'lat'))
r5 = BaggingRegressor(**get_hyperparameter('BaggingRegressor', 'lat'))
Vr_lat = VotingRegressor(estimators=[('Et',r1),('Rf',r2),('Gb',r3),('Xg',r4),('Xdg',r5)])

y_pred_lng = cross_val_predict(Vr_lng, df_feat_new_TRAIN, y_full.lng, cv=3)
y_pred_lat = cross_val_predict(Vr_lat, df_feat_new_TRAIN, y_full.lat, cv=3)

err_vec = Eval_geoloc(y_full.lat , y_full.lng, y_pred_lat, y_pred_lng)
np.percentile(err_vec, 80)
# Out:
# 2.8407256000000003

# %% [markdown]
# # Prédiction du Test

# %%
df=X_test
df_feat, id_list=feat_mat_const(df, listOfBs)
df_temp = df_feat[df_feat.columns[:-14]]
df_group = df.groupby("messid", as_index=False)
nb_mess = len(df.messid.unique())
df_feat_new = pd.DataFrame(np.zeros((nb_mess, len(listOfBs))), columns=listOfBs, index=df.messid.unique())

# %%
# %%time
for idx,base in enumerate(df_temp.columns):
    print(f"Base : {base}")
    #Prod de la sous matrice df_feat (lié à la base)
    df_feat_reduce=df_temp[df_temp[base]!=0]
    print(f"Nb message : {df_feat_reduce.shape[0]}")
    if df_feat_reduce.shape[0]:
        if Models.get(base,False) :
            X=[]
            #On parcours tous les messages identifié à une base
            for i,k in enumerate(df_feat_reduce.index):
                for j in df_temp.columns: #Je parcours toutes les bases et construit la matrice 259x259
                    X.append(abs(df_temp.loc[k,j]-df_temp.loc[k,df_temp.columns]).values)
            X=np.array(X)
            y= Models[base][1].predict(X)
            sol=[]
            for j in range(y.shape[0]//size):
                sol.append(y[j*size:(j+1)*size][Models[base][0]])
            df_feat_new.loc[df_feat_reduce.index.values,base]=np.array(sol)
        else:
            print(f"Base non modélisée {base}")
            """Ici on pourrait prévoire un amélioration qui une fois le message prédit on construit le modèle"""
    else :
        print(f"Base sans message {base}")
# Out:
# Base : 879
# Nb message : 0
# Base sans message 879
# Base : 911
# Nb message : 0
# Base sans message 911
# Base : 921
# Nb message : 0
# Base sans message 921
# Base : 944
# Nb message : 0
# Base sans message 944
# Base : 980
# Nb message : 0
# Base sans message 980
# Base : 1012
# Nb message : 80
# Base : 1086
# Nb message : 38
# Base : 1092
# Nb message : 2
# Base : 1120
# Nb message : 0
# Base sans message 1120
# Base : 1131
# Nb message : 2
# Base non modélisée 1131
# Base : 1148
# Nb message : 0
# Base sans message 1148
# Base : 1156
# Nb message : 0
# Base sans message 1156
# Base : 1187
# Nb message : 0
# Base sans message 1187
# Base : 1226
# Nb message : 0
# Base sans message 1226
# Base : 1229
# Nb message : 0
# Base sans message 1229
# Base : 1235
# Nb message : 0
# Base sans message 1235
# Base : 1237
# Nb message : 0
# Base sans message 1237
# Base : 1264
# Nb message : 193
# Base : 1266
# Nb message : 0
# Base sans message 1266
# Base : 1268
# Nb message : 12
# Base : 1292
# Nb message : 1
# Base : 1334
# Nb message : 2
# Base : 1344
# Nb message : 5
# Base : 1432
# Nb message : 1
# Base : 1443
# Nb message : 0
# Base sans message 1443
# Base : 1447
# Nb message : 0
# Base sans message 1447
# Base : 1463
# Nb message : 0
# Base sans message 1463
# Base : 1476
# Nb message : 356
# Base : 1526
# Nb message : 0
# Base sans message 1526
# Base : 1530
# Nb message : 2
# Base : 1534
# Nb message : 0
# Base sans message 1534
# Base : 1581
# Nb message : 0
# Base sans message 1581
# Base : 1594
# Nb message : 257
# Base : 1661
# Nb message : 33
# Base : 1730
# Nb message : 0
# Base sans message 1730
# Base : 1741
# Nb message : 268
# Base : 1743
# Nb message : 120
# Base : 1772
# Nb message : 44
# Base : 1796
# Nb message : 232
# Base : 1826
# Nb message : 2
# Base : 1828
# Nb message : 0
# Base sans message 1828
# Base : 1838
# Nb message : 0
# Base sans message 1838
# Base : 1852
# Nb message : 0
# Base sans message 1852
# Base : 1854
# Nb message : 15
# Base : 1859
# Nb message : 809
# Base : 1872
# Nb message : 262
# Base : 1878
# Nb message : 592
# Base : 1971
# Nb message : 0
# Base sans message 1971
# Base : 1987
# Nb message : 183
# Base : 1988
# Nb message : 73
# Base : 1994
# Nb message : 29
# Base : 1996
# Nb message : 307
# Base : 2189
# Nb message : 370
# Base : 2293
# Nb message : 0
# Base sans message 2293
# Base : 2605
# Nb message : 624
# Base : 2610
# Nb message : 389
# Base : 2611
# Nb message : 0
# Base sans message 2611
# Base : 2617
# Nb message : 709
# Base : 2693
# Nb message : 2
# Base : 2707
# Nb message : 67
# Base : 2731
# Nb message : 276
# Base : 2737
# Nb message : 18
# Base : 2762
# Nb message : 2
# Base : 2765
# Nb message : 0
# Base sans message 2765
# Base : 2766
# Nb message : 0
# Base sans message 2766
# Base : 2768
# Nb message : 7
# Base : 2770
# Nb message : 0
# Base sans message 2770
# Base : 2775
# Nb message : 0
# Base sans message 2775
# Base : 2776
# Nb message : 5
# Base : 2780
# Nb message : 0
# Base sans message 2780
# Base : 2784
# Nb message : 95
# Base : 2790
# Nb message : 166
# Base : 2799
# Nb message : 307
# Base : 2800
# Nb message : 0
# Base sans message 2800
# Base : 2803
# Nb message : 0
# Base sans message 2803
# Base : 2808
# Nb message : 0
# Base sans message 2808
# Base : 2831
# Nb message : 18
# Base : 2836
# Nb message : 0
# Base sans message 2836
# Base : 2837
# Nb message : 6
# Base : 2841
# Nb message : 8
# Base : 2842
# Nb message : 12
# Base : 2845
# Nb message : 0
# Base sans message 2845
# Base : 2846
# Nb message : 688
# Base : 2849
# Nb message : 0
# Base sans message 2849
# Base : 2855
# Nb message : 0
# Base sans message 2855
# Base : 2862
# Nb message : 119
# Base : 2943
# Nb message : 26
# Base : 2945
# Nb message : 0
# Base sans message 2945
# Base : 2999
# Nb message : 459
# Base : 3025
# Nb message : 1066
# Base : 3034
# Nb message : 2
# Base non modélisée 3034
# Base : 3041
# Nb message : 0
# Base sans message 3041
# Base : 3051
# Nb message : 68
# Base : 3256
# Nb message : 9
# Base : 3357
# Nb message : 73
# Base : 3378
# Nb message : 33
# Base : 3385
# Nb message : 0
# Base sans message 3385
# Base : 3386
# Nb message : 347
# Base : 3389
# Nb message : 13
# Base : 3402
# Nb message : 74
# Base : 3403
# Nb message : 368
# Base : 3410
# Nb message : 323
# Base : 3412
# Nb message : 175
# Base : 3414
# Nb message : 133
# Base : 3415
# Nb message : 145
# Base : 3500
# Nb message : 351
# Base : 3501
# Nb message : 0
# Base sans message 3501
# Base : 3515
# Nb message : 0
# Base sans message 3515
# Base : 3526
# Nb message : 37
# Base : 3527
# Nb message : 14
# Base : 3529
# Nb message : 114
# Base : 3535
# Nb message : 1
# Base : 3536
# Nb message : 14
# Base : 3538
# Nb message : 195
# Base : 3544
# Nb message : 0
# Base sans message 3544
# Base : 3545
# Nb message : 104
# Base : 3546
# Nb message : 0
# Base sans message 3546
# Base : 3547
# Nb message : 772
# Base : 3548
# Nb message : 467
# Base : 3549
# Nb message : 0
# Base sans message 3549
# Base : 3553
# Nb message : 7
# Base : 3554
# Nb message : 18
# Base : 3555
# Nb message : 2
# Base : 3556
# Nb message : 475
# Base : 3558
# Nb message : 130
# Base : 3559
# Nb message : 130
# Base : 3562
# Nb message : 606
# Base : 3563
# Nb message : 473
# Base : 3565
# Nb message : 73
# Base : 3568
# Nb message : 2
# Base : 3569
# Nb message : 76
# Base : 3570
# Nb message : 488
# Base : 3571
# Nb message : 8
# Base : 3572
# Nb message : 0
# Base sans message 3572
# Base : 3574
# Nb message : 126
# Base : 3575
# Nb message : 3
# Base : 3576
# Nb message : 81
# Base : 3577
# Nb message : 0
# Base sans message 3577
# Base : 3578
# Nb message : 607
# Base : 3579
# Nb message : 464
# Base : 3581
# Nb message : 285
# Base : 3613
# Nb message : 0
# Base sans message 3613
# Base : 3629
# Nb message : 6
# Base : 3630
# Nb message : 0
# Base sans message 3630
# Base : 3646
# Nb message : 0
# Base sans message 3646
# Base : 3828
# Nb message : 2
# Base non modélisée 3828
# Base : 3835
# Nb message : 1
# Base : 3846
# Nb message : 360
# Base : 3848
# Nb message : 0
# Base sans message 3848
# Base : 3907
# Nb message : 3
# Base : 3915
# Nb message : 0
# Base sans message 3915
# Base : 3933
# Nb message : 0
# Base sans message 3933
# Base : 3983
# Nb message : 19
# Base : 4013
# Nb message : 0
# Base sans message 4013
# Base : 4024
# Nb message : 0
# Base sans message 4024
# Base : 4047
# Nb message : 7
# Base : 4049
# Nb message : 0
# Base sans message 4049
# Base : 4055
# Nb message : 0
# Base sans message 4055
# Base : 4056
# Nb message : 247
# Base : 4058
# Nb message : 817
# Base : 4059
# Nb message : 345
# Base : 4060
# Nb message : 0
# Base sans message 4060
# Base : 4064
# Nb message : 37
# Base : 4065
# Nb message : 1
# Base : 4073
# Nb message : 0
# Base sans message 4073
# Base : 4078
# Nb message : 266
# Base : 4088
# Nb message : 0
# Base sans message 4088
# Base : 4092
# Nb message : 21
# Base : 4105
# Nb message : 1
# Base : 4123
# Nb message : 0
# Base sans message 4123
# Base : 4129
# Nb message : 54
# Base : 4147
# Nb message : 198
# Base : 4148
# Nb message : 12
# Base : 4156
# Nb message : 166
# Base : 4157
# Nb message : 435
# Base : 4205
# Nb message : 6
# Base : 4244
# Nb message : 252
# Base : 4646
# Nb message : 5
# Base : 4790
# Nb message : 0
# Base sans message 4790
# Base : 4813
# Nb message : 0
# Base sans message 4813
# Base : 4819
# Nb message : 32
# Base : 4959
# Nb message : 0
# Base sans message 4959
# Base : 4966
# Nb message : 12
# Base : 4987
# Nb message : 120
# Base : 4993
# Nb message : 441
# Base : 4996
# Nb message : 0
# Base sans message 4996
# Base : 7248
# Nb message : 2
# Base : 7378
# Nb message : 0
# Base sans message 7378
# Base : 7382
# Nb message : 381
# Base : 7435
# Nb message : 3
# Base : 7456
# Nb message : 603
# Base : 7490
# Nb message : 0
# Base sans message 7490
# Base : 7508
# Nb message : 0
# Base sans message 7508
# Base : 7628
# Nb message : 0
# Base sans message 7628
# Base : 7655
# Nb message : 0
# Base sans message 7655
# Base : 7673
# Nb message : 0
# Base sans message 7673
# Base : 7692
# Nb message : 83
# Base : 7726
# Nb message : 40
# Base : 7738
# Nb message : 77
# Base : 7789
# Nb message : 46
# Base : 7807
# Nb message : 0
# Base sans message 7807
# Base : 7849
# Nb message : 0
# Base sans message 7849
# Base : 7857
# Nb message : 0
# Base sans message 7857
# Base : 7972
# Nb message : 0
# Base sans message 7972
# Base : 7986
# Nb message : 0
# Base sans message 7986
# Base : 8079
# Nb message : 0
# Base sans message 8079
# Base : 8082
# Nb message : 39
# Base : 8168
# Nb message : 1
# Base non modélisée 8168
# Base : 8226
# Nb message : 0
# Base sans message 8226
# Base : 8242
# Nb message : 0
# Base sans message 8242
# Base : 8245
# Nb message : 454
# Base : 8351
# Nb message : 4
# Base : 8352
# Nb message : 432
# Base : 8355
# Nb message : 465
# Base : 8356
# Nb message : 667
# Base : 8364
# Nb message : 212
# Base : 8368
# Nb message : 7
# Base : 8370
# Nb message : 207
# Base : 8371
# Nb message : 3
# Base : 8384
# Nb message : 0
# Base sans message 8384
# Base : 8390
# Nb message : 0
# Base sans message 8390
# Base : 8392
# Nb message : 1
# Base : 8397
# Nb message : 408
# Base : 8401
# Nb message : 0
# Base sans message 8401
# Base : 8405
# Nb message : 0
# Base sans message 8405
# Base : 8426
# Nb message : 27
# Base : 8437
# Nb message : 462
# Base : 8442
# Nb message : 0
# Base sans message 8442
# Base : 8446
# Nb message : 434
# Base : 8449
# Nb message : 25
# Base : 8450
# Nb message : 12
# Base : 8451
# Nb message : 30
# Base : 8452
# Nb message : 177
# Base : 8453
# Nb message : 3
# Base : 8457
# Nb message : 4
# Base : 8470
# Nb message : 116
# Base : 8471
# Nb message : 88
# Base : 8472
# Nb message : 453
# Base : 8473
# Nb message : 121
# Base : 8474
# Nb message : 437
# Base : 8475
# Nb message : 76
# Base : 8495
# Nb message : 0
# Base sans message 8495
# Base : 8509
# Nb message : 72
# Base : 8560
# Nb message : 8
# Base : 8746
# Nb message : 107
# Base : 8747
# Nb message : 1
# Base : 9783
# Nb message : 22
# Base non modélisée 9783
# Base : 9784
# Nb message : 0
# Base sans message 9784
# Base : 9899
# Nb message : 397
# Base : 9936
# Nb message : 4
# Base non modélisée 9936
# Base : 9941
# Nb message : 3
# Base non modélisée 9941
# Base : 9949
# Nb message : 2
# Base non modélisée 9949
# Base : 10134
# Nb message : 2
# Base : 10148
# Nb message : 0
# Base sans message 10148
# Base : 10151
# Nb message : 297
# Base : 10162
# Nb message : 503
# Base : 10999
# Nb message : 0
# Base sans message 10999
# Base : 11007
# Nb message : 157
# Base : 11951
# Nb message : 0
# Base sans message 11951
# Wall time: 1h 9min 58s

# %%
df_feat_new_TEST = pd.merge(df_feat_new,df_feat[df_feat.columns[-14:]],right_index=True,left_index=True)

# %%
"""NE PAS RUNNER"""
with open (f"df_feat_new_TEST.pkl","wb") as fp :
    pickle.dump(df_feat_new_TEST, fp)

# %%
""" Runner cette cellule pour charger la df Feat du X_test"""
with open (f"df_feat_new_TEST.pkl","rb") as fp :
    df_feat_new_TEST = pickle.load(fp)

# %%
r1 = RandomForestRegressor(**get_hyperparameter('RandomForestRegressor', 'lng'))
r2 = GradientBoostingRegressor(**get_hyperparameter('GradientBoostingRegressor', 'lng'))
r3 = ExtraTreeRegressor(**get_hyperparameter('ExtraTreeRegressor', 'lng'))
r4 = xgb.XGBRegressor(**get_hyperparameter('XGBRegressor', 'lng'))
r5 = BaggingRegressor(**get_hyperparameter('BaggingRegressor', 'lng'))
Vr_lng = VotingRegressor(estimators=[('Et',r1),('Rf',r2),('Gb',r3),('Xg',r4),('Xdg',r5)])


r1 = RandomForestRegressor(**get_hyperparameter('RandomForestRegressor', 'lat'))
r2 = GradientBoostingRegressor(**get_hyperparameter('GradientBoostingRegressor', 'lat'))
r3 = ExtraTreeRegressor(**get_hyperparameter('ExtraTreeRegressor', 'lat'))
r4 = xgb.XGBRegressor(**get_hyperparameter('XGBRegressor', 'lat'))
r5 = BaggingRegressor(**get_hyperparameter('BaggingRegressor', 'lat'))
Vr_lat = VotingRegressor(estimators=[('Et',r1),('Rf',r2),('Gb',r3),('Xg',r4),('Xdg',r5)])

Vr_lng.fit(df_feat_new_TRAIN, y_full.lng)
Vr_lat.fit(df_feat_new_TRAIN, y_full.lat)

y_pred_lng = Vr_lng.predict(df_feat_new_TEST)
y_pred_lat = Vr_lat.predict(df_feat_new_TEST)

#Il faut produire le fichier solution

# %%
y_pred_lng
# Out:
# array([-105.12001468, -105.08099715, -105.01428986, ..., -105.03130442,
#        -105.02338449, -105.02420362])

# %%
y_pred_lat
# Out:
# array([39.72055927, 39.77837919, 39.6900661 , ..., 39.69068253,
#        39.67845017, 39.68752195])

# %%
from ipyleaflet import Map, basemaps
msg_test = pd.DataFrame({'lat':y_pred_lat,'lng':y_pred_lng},index=df_feat_new_TEST.index)

barycentre = ((msg_test.lat.max()+msg_test.lat.min())/2,(msg_test.lng.min()+msg_test.lng.max())/2)

m = Map(center=barycentre, zoom=3, basemap = basemaps.OpenStreetMap.Mapnik)

message = Give_Marker_Cluster(msg_test)

m.add_layer(message)

m
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-28-466c03e4bd72> in <module>
# ----> 1 from ipyleaflet import Map, basemaps
#       2 msg_test = pd.DataFrame({'lat':y_pred_lat,'lng':y_pred_lng},index=df_feat_new_TEST.index)
#       3
#       4 barycentre = ((msg_test.lat.max()+msg_test.lat.min())/2,(msg_test.lng.min()+msg_test.lng.max())/2)
#       5
#
# C:\Dev\Anaconda\lib\site-packages\ipyleaflet\__init__.py in <module>
#       9
#      10 try:
# ---> 11     from .leaflet import *  # noqa
#      12     from .basemaps import basemaps   # noqa
#      13 except ImportError:
#
# C:\Dev\Anaconda\lib\site-packages\ipyleaflet\leaflet.py in <module>
#      21
#      22 from branca.colormap import linear, ColorMap
# ---> 23 from shapely import geometry, wkt
#      24
#      25 from ._version import EXTENSION_VERSION
#
# C:\Dev\Anaconda\lib\site-packages\shapely\geometry\__init__.py in <module>
#       2 """
#       3
# ----> 4 from .base import CAP_STYLE, JOIN_STYLE
#       5 from .geo import box, shape, asShape, mapping
#       6 from .point import Point, asPoint
#
# C:\Dev\Anaconda\lib\site-packages\shapely\geometry\base.py in <module>
#      17
#      18 from shapely.affinity import affine_transform
# ---> 19 from shapely.coords import CoordinateSequence
#      20 from shapely.errors import WKBReadingError, WKTReadingError
#      21 from shapely.geos import WKBWriter, WKTWriter
#
# C:\Dev\Anaconda\lib\site-packages\shapely\coords.py in <module>
#       6 from ctypes import byref, c_double, c_uint
#       7
# ----> 8 from shapely.geos import lgeos
#       9 from shapely.topology import Validating
#      10
#
# C:\Dev\Anaconda\lib\site-packages\shapely\geos.py in <module>
#     152     if os.getenv('CONDA_PREFIX', ''):
#     153         # conda package.
# --> 154         _lgeos = CDLL(os.path.join(sys.prefix, 'Library', 'bin', 'geos_c.dll'))
#     155     else:
#     156         try:
#
# C:\Dev\Anaconda\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: [WinError 126] Le module spécifié est introuvable
